# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Lectura archivo
path = ruta_del_archivo = '../data/online_news_modified.csv'
news_df = pd.read_csv(path)
news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40436 entries, 0 to 40435
# Data columns (total 62 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            40027 non-null  object
#  1   timedelta                      39994 non-null  object
#  2   n_tokens_title                 39976 non-null  object
#  3   n_tokens_content               39963 non-null  object
#  4   n_unique_tokens                39985 non-null  object
#  5   n_non_stop_words               39977 non-null  object
#  6   n_non_stop_unique_tokens       39956 non-null  object
#  7   num_hrefs                      39986 non-null  object
#  8   num_self_hrefs                 39988 non-null  object
#  9   num_imgs                       39980 non-null  object
#  10  num_videos                     39987 non-null  object
#  11  average_token_length           40031 non-null  object
#  12  num_keywords                   39981 non-null  object
#  13  data_channel_is_lifestyle      39961 non-null  object
#  14  data_channel_is_entertainment  39951 non-null  object
#  15  data_channel_is_bus            40029 non-null  object
#  16  data_channel_is_socmed         39944 non-null  object
#  17  data_channel_is_tech           39993 non-null  object
#  18  data_channel_is_world          39984 non-null  object
#  19  kw_min_min                     39984 non-null  object
#  20  kw_max_min                     39972 non-null  object
#  21  kw_avg_min                     39965 non-null  object
#  22  kw_min_max                     39995 non-null  object
#  23  kw_max_max                     40031 non-null  object
#  24  kw_avg_max                     39958 non-null  object
#  25  kw_min_avg                     40004 non-null  object
#  26  kw_max_avg                     39996 non-null  object
#  27  kw_avg_avg                     40035 non-null  object
#  28  self_reference_min_shares      39997 non-null  object
#  29  self_reference_max_shares      39972 non-null  object
#  30  self_reference_avg_sharess     39970 non-null  object
#  31  weekday_is_monday              39977 non-null  object
#  32  weekday_is_tuesday             39977 non-null  object
#  33  weekday_is_wednesday           40015 non-null  object
#  34  weekday_is_thursday            39977 non-null  object
#  35  weekday_is_friday              40007 non-null  object
#  36  weekday_is_saturday            39980 non-null  object
#  37  weekday_is_sunday              39966 non-null  object
#  38  is_weekend                     39969 non-null  object
#  39  LDA_00                         39945 non-null  object
#  40  LDA_01                         39982 non-null  object
#  41  LDA_02                         39953 non-null  object
#  42  LDA_03                         39989 non-null  object
#  43  LDA_04                         39980 non-null  object
#  44  global_subjectivity            39999 non-null  object
#  45  global_sentiment_polarity      39996 non-null  object
#  46  global_rate_positive_words     39991 non-null  object
#  47  global_rate_negative_words     39948 non-null  object
#  48  rate_positive_words            39983 non-null  object
#  49  rate_negative_words            39956 non-null  object
#  50  avg_positive_polarity          39978 non-null  object
#  51  min_positive_polarity          39953 non-null  object
#  52  max_positive_polarity          39979 non-null  object
#  53  avg_negative_polarity          39975 non-null  object
#  54  min_negative_polarity          39976 non-null  object
#  55  max_negative_polarity          39996 non-null  object
#  56  title_subjectivity             39983 non-null  object
#  57  title_sentiment_polarity       39950 non-null  object
#  58  abs_title_subjectivity         39961 non-null  object
#  59  abs_title_sentiment_polarity   39981 non-null  object
#  60  shares                         39949 non-null  object
#  61  mixed_type_col                 36362 non-null  object
# dtypes: object(62)
# memory usage: 19.1+ MB

# %%
news_df.head()
# Out:
#                                                  url timedelta n_tokens_title  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...     731.0           12.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...     731.0            9.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...     731.0            9.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...     731.0            9.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/     731.0           13.0
#
#   n_tokens_content  n_unique_tokens n_non_stop_words n_non_stop_unique_tokens  \
# 0            219.0   0.663594466988   0.999999992308           0.815384609112
# 1            255.0   0.604743080614   0.999999993289            0.79194630341
# 2            211.0   0.575129530699   0.999999991597            0.66386554064
# 3            531.0   0.503787877834   0.999999996904           0.665634672862
# 4           1072.0   0.41564561695    0.999999998565           0.540889525766
#
#   num_hrefs num_self_hrefs num_imgs  ... max_positive_polarity  \
# 0       4.0            2.0      1.0  ...                   0.7
# 1       3.0            1.0      1.0  ...                   0.7
# 2      3.0             1.0     1.0   ...                   1.0
# 3       9.0            0.0      1.0  ...                   0.8
# 4      19.0           19.0     20.0  ...                   1.0
#
#   avg_negative_polarity min_negative_polarity max_negative_polarity  \
# 0                 -0.35                  -0.6   -3.4000000000000004
# 1              -0.11875                -0.125                  -0.1
# 2       -0.466666666667                  -0.8       -0.133333333333
# 3       -0.369696969697                  -0.6       -0.166666666667
# 4       -0.220192307692                 error                 -0.05
#
#   title_subjectivity title_sentiment_polarity abs_title_subjectivity  \
# 0                0.5                  -0.1875                   0.0
# 1                0.0                      0.0                    0.5
# 2                0.0                      0.0                    0.5
# 3                0.0                      0.0                    0.5
# 4     0.454545454545           0.136363636364        0.0454545454545
#
#   abs_title_sentiment_polarity    shares mixed_type_col
# 0                       0.1875     593.0            bad
# 1                          0.0     711.0            639
# 2                          0.0   1500.0         unknown
# 3                          NaN    1200.0            688
# 4               0.136363636364     505.0            579
#
# [5 rows x 62 columns]

# %%
# Obtiene los string dentro de todos los datos numericos, para sustituirlos por NaN


def es_string_real(valor):
    """
    Devuelve True si el valor es un string y no se puede
    convertir a un número de punto flotante (float).
    """
    try:
        # Intenta convertir el valor a float.
        float(valor)
        # Si tiene éxito, significa que es un número (o un string numérico).
        # En ese caso, no es un "string real".
        return False
    except (ValueError, TypeError):
        # Si la conversión falla con un error, significa que el valor
        # no es numérico (ej: "Error_1"), por lo tanto es un string real.
        # El TypeError se añade para manejar valores que no son ni string
        # ni número, como None o listas.
        return True
    

all_values = news_df.iloc[:, 1:].stack()

# b. Filtramos la Serie para quedarnos únicamente con los valores que son de tipo string (str).
string_series_reales = all_values[all_values.apply(es_string_real)]

# c. Convertimos la Serie filtrada a una lista para conocer que palabras tenemos en los datos.
list_de_strings = list(set(string_series_reales))

print(list_de_strings)
# Out:
# ['?', 'bad', ' INVALID ', 'invalid', 'unknown', ' ? ', 'error', ' n/a ', ' null ', ' ERROR ']

# %%
# Como todas la palabras indican que debe ser un valor nulo, es decir transformalos a NaN

news_df = news_df.replace(list_de_strings, np.nan)

# Columnas a convertir en numericos
cols_to_convert = news_df.columns[1:]

news_df[cols_to_convert] = news_df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40436 entries, 0 to 40435
# Data columns (total 62 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            40027 non-null  object
#  1   timedelta                      39839 non-null  float64
#  2   n_tokens_title                 39822 non-null  float64
#  3   n_tokens_content               39805 non-null  float64
#  4   n_unique_tokens                39834 non-null  float64
#  5   n_non_stop_words               39855 non-null  float64
#  6   n_non_stop_unique_tokens       39799 non-null  float64
#  7   num_hrefs                      39839 non-null  float64
#  8   num_self_hrefs                 39828 non-null  float64
#  9   num_imgs                       39840 non-null  float64
#  10  num_videos                     39849 non-null  float64
#  11  average_token_length           39902 non-null  float64
#  12  num_keywords                   39831 non-null  float64
#  13  data_channel_is_lifestyle      39823 non-null  float64
#  14  data_channel_is_entertainment  39824 non-null  float64
#  15  data_channel_is_bus            39888 non-null  float64
#  16  data_channel_is_socmed         39794 non-null  float64
#  17  data_channel_is_tech           39853 non-null  float64
#  18  data_channel_is_world          39845 non-null  float64
#  19  kw_min_min                     39833 non-null  float64
#  20  kw_max_min                     39815 non-null  float64
#  21  kw_avg_min                     39823 non-null  float64
#  22  kw_min_max                     39835 non-null  float64
#  23  kw_max_max                     39873 non-null  float64
#  24  kw_avg_max                     39829 non-null  float64
#  25  kw_min_avg                     39852 non-null  float64
#  26  kw_max_avg                     39857 non-null  float64
#  27  kw_avg_avg                     39898 non-null  float64
#  28  self_reference_min_shares      39832 non-null  float64
#  29  self_reference_max_shares      39842 non-null  float64
#  30  self_reference_avg_sharess     39816 non-null  float64
#  31  weekday_is_monday              39821 non-null  float64
#  32  weekday_is_tuesday             39817 non-null  float64
#  33  weekday_is_wednesday           39880 non-null  float64
#  34  weekday_is_thursday            39832 non-null  float64
#  35  weekday_is_friday              39845 non-null  float64
#  36  weekday_is_saturday            39808 non-null  float64
#  37  weekday_is_sunday              39818 non-null  float64
#  38  is_weekend                     39809 non-null  float64
#  39  LDA_00                         39808 non-null  float64
#  40  LDA_01                         39845 non-null  float64
#  41  LDA_02                         39807 non-null  float64
#  42  LDA_03                         39846 non-null  float64
#  43  LDA_04                         39835 non-null  float64
#  44  global_subjectivity            39857 non-null  float64
#  45  global_sentiment_polarity      39847 non-null  float64
#  46  global_rate_positive_words     39861 non-null  float64
#  47  global_rate_negative_words     39790 non-null  float64
#  48  rate_positive_words            39840 non-null  float64
#  49  rate_negative_words            39814 non-null  float64
#  50  avg_positive_polarity          39833 non-null  float64
#  51  min_positive_polarity          39803 non-null  float64
#  52  max_positive_polarity          39832 non-null  float64
#  53  avg_negative_polarity          39830 non-null  float64
#  54  min_negative_polarity          39832 non-null  float64
#  55  max_negative_polarity          39863 non-null  float64
#  56  title_subjectivity             39835 non-null  float64
#  57  title_sentiment_polarity       39809 non-null  float64
#  58  abs_title_subjectivity         39808 non-null  float64
#  59  abs_title_sentiment_polarity   39824 non-null  float64
#  60  shares                         39805 non-null  float64
#  61  mixed_type_col                 28379 non-null  float64
# dtypes: float64(61), object(1)
# memory usage: 19.1+ MB

# %%
# De la columna URL, se deben eliminar las entradas nulas o vacias, pues si no se puede asociar a una web no es identificable

# Elimina los vacios
news_df = news_df[news_df['url'].notna() & (news_df['url'] != '')]

# lo convierte en string
news_df['url'] = news_df['url'].astype(str)
news_df['url'] = news_df['url'].str.lower()

# Elimina espacios antes y despues del url
news_df['url'] = news_df['url'].str.strip()

# Guarda solo los datos que empiezan con http
news_df = news_df[news_df['url'].str.startswith('http', na=False)]

news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40010 entries, 0 to 40435
# Data columns (total 62 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            40010 non-null  object
#  1   timedelta                      39418 non-null  float64
#  2   n_tokens_title                 39403 non-null  float64
#  3   n_tokens_content               39386 non-null  float64
#  4   n_unique_tokens                39410 non-null  float64
#  5   n_non_stop_words               39436 non-null  float64
#  6   n_non_stop_unique_tokens       39381 non-null  float64
#  7   num_hrefs                      39420 non-null  float64
#  8   num_self_hrefs                 39407 non-null  float64
#  9   num_imgs                       39418 non-null  float64
#  10  num_videos                     39429 non-null  float64
#  11  average_token_length           39484 non-null  float64
#  12  num_keywords                   39417 non-null  float64
#  13  data_channel_is_lifestyle      39402 non-null  float64
#  14  data_channel_is_entertainment  39405 non-null  float64
#  15  data_channel_is_bus            39469 non-null  float64
#  16  data_channel_is_socmed         39372 non-null  float64
#  17  data_channel_is_tech           39434 non-null  float64
#  18  data_channel_is_world          39424 non-null  float64
#  19  kw_min_min                     39412 non-null  float64
#  20  kw_max_min                     39393 non-null  float64
#  21  kw_avg_min                     39403 non-null  float64
#  22  kw_min_max                     39415 non-null  float64
#  23  kw_max_max                     39454 non-null  float64
#  24  kw_avg_max                     39414 non-null  float64
#  25  kw_min_avg                     39429 non-null  float64
#  26  kw_max_avg                     39435 non-null  float64
#  27  kw_avg_avg                     39478 non-null  float64
#  28  self_reference_min_shares      39407 non-null  float64
#  29  self_reference_max_shares      39421 non-null  float64
#  30  self_reference_avg_sharess     39397 non-null  float64
#  31  weekday_is_monday              39407 non-null  float64
#  32  weekday_is_tuesday             39401 non-null  float64
#  33  weekday_is_wednesday           39456 non-null  float64
#  34  weekday_is_thursday            39410 non-null  float64
#  35  weekday_is_friday              39426 non-null  float64
#  36  weekday_is_saturday            39384 non-null  float64
#  37  weekday_is_sunday              39397 non-null  float64
#  38  is_weekend                     39392 non-null  float64
#  39  LDA_00                         39391 non-null  float64
#  40  LDA_01                         39423 non-null  float64
#  41  LDA_02                         39385 non-null  float64
#  42  LDA_03                         39426 non-null  float64
#  43  LDA_04                         39413 non-null  float64
#  44  global_subjectivity            39436 non-null  float64
#  45  global_sentiment_polarity      39429 non-null  float64
#  46  global_rate_positive_words     39445 non-null  float64
#  47  global_rate_negative_words     39372 non-null  float64
#  48  rate_positive_words            39417 non-null  float64
#  49  rate_negative_words            39392 non-null  float64
#  50  avg_positive_polarity          39411 non-null  float64
#  51  min_positive_polarity          39387 non-null  float64
#  52  max_positive_polarity          39416 non-null  float64
#  53  avg_negative_polarity          39412 non-null  float64
#  54  min_negative_polarity          39412 non-null  float64
#  55  max_negative_polarity          39443 non-null  float64
#  56  title_subjectivity             39414 non-null  float64
#  57  title_sentiment_polarity       39392 non-null  float64
#  58  abs_title_subjectivity         39396 non-null  float64
#  59  abs_title_sentiment_polarity   39406 non-null  float64
#  60  shares                         39386 non-null  float64
#  61  mixed_type_col                 28072 non-null  float64
# dtypes: float64(61), object(1)
# memory usage: 19.2+ MB

# %%
# Porcentaje de datos nulos por columna

porcentaje_nulos = (news_df.isnull().sum() / len(news_df)) * 100
print(porcentaje_nulos)
# Out:
# url                              0.000000
# timedelta                        1.479630
# n_tokens_title                   1.517121
# n_tokens_content                 1.559610
# n_unique_tokens                  1.499625
#                                   ...
# title_sentiment_polarity         1.544614
# abs_title_subjectivity           1.534616
# abs_title_sentiment_polarity     1.509623
# shares                           1.559610
# mixed_type_col                  29.837541
# Length: 62, dtype: float64
