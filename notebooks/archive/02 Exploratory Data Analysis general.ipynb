# %% [markdown]
# 1. Importar librerías

# %%
# ==========================================
# 1. Importar librerías
# ==========================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", palette="muted")
plt.rcParams["figure.figsize"] = (10, 6)

# %% [markdown]
# 2. Cargar dataset limpio

# %%
# ==========================================
# 2. Cargar dataset limpio
# ==========================================
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
file_path = os.path.join(project_root, "data/processed/online_news_cleaned.csv")

df = pd.read_csv(file_path)
df.head()

# %%
# Tamaño del dataset
df.shape

# %%
# Variables estadísticas rápidas
df.describe().T

# %%
# Nulos (NO deberías tener nulos)
df.isna().sum().sort_values(ascending=False)

# %% [markdown]
# 4. Distribución de la variable objetivo (shares)

# %%
sns.histplot(df["shares"], bins=50, kde=True)
plt.title("Distribución de Shares")
plt.show()

# %%
sns.boxplot(x=df["shares"])
plt.title("Shares - Outliers")
plt.show()

# %% [markdown]
# 6. Correlaciones (Heatmap)

# %%
# Solo columnas numéricas para evitar errores
numeric_df = df.select_dtypes(include=[np.number])

corr = numeric_df.corr()

plt.figure(figsize=(16, 12))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Mapa de correlaciones (solo variables numéricas)")
plt.show()

# %% [markdown]
# # 🟦 Grupo A — Variables de tokens (texto)
#
# **Variables:**
# - `n_tokens_title`
# - `n_tokens_content`
# - `n_unique_tokens`
# - `n_non_stop_words`
# - `n_non_stop_unique_tokens`
# - `average_token_length`
#
# **👉 Aquí evaluamos:**
# - longitud del texto
# - riqueza léxica
# - repetición de palabras
# - variabilidad
#
#
# # 🟩 Grupo B — Variables de contenido multimedia
#
# **Variables:**
# - `num_imgs`
# - `num_videos`
#
# **👉 Aquí evaluamos:**
# - si el artículo es visual o no
# - distribución muy sesgada (la mayoría tiene pocos videos/imágenes)
#
#
# # 🟧 Grupo C — Keywords (`kw_*`)
#
# **Variables:**
# - `kw_min_min`
# - `kw_max_min`
# - `kw_avg_min`
# - `kw_min_max`
# - `kw_avg_max`
# - `kw_max_avg`
# - `kw_min_avg`
# - `kw_max_avg`
# - `kw_avg_avg`
#
# **👉 Este grupo es complejo y requiere:**
# - análisis de correlación con `shares`
# - reducción de dimensionalidad (PCA o selección de features)
# - limpieza de valores inválidos (`-1`)
#
#
# # 🟪 Grupo D — Variables categóricas (dummies por canal y día)
#
# **Variables:**
# - `data_channel_is_*`
# - `weekday_is_*`
# - `is_weekend`
#
# **👉 Aquí analizamos:**
# - qué canales publican contenido más viral
# - qué días generan más shares
#
#
# # 🟫 Grupo E — Variables de sentimiento
#
# **Variables:**
# - `global_subjectivity`
# - `global_sentiment_polarity`
# - `global_rate_positive_words`
# - `global_rate_negative_words`
# - `avg_positive_polarity`
# - `avg_negative_polarity`
# - `title_subjectivity`
# - `title_sentiment_polarity`
# - `abs_title_subjectivity`
# - `abs_title_sentiment_polarity`
#
# **👉 Debes analizar:**
# - relación entre sentimiento y shares
# - si una polaridad extrema genera más viralidad
# - si sentimientos positivos/negativos afectan la difusión
#
#
# # 🟥 Grupo F — Variables del propio artículo
#
# **Variables:**
# - `url`
# - `timedelta`
# - `self_reference_*`
#
# **👉 Aquí analizas:**
# - antigüedad del artículo
# - si se referencia a sí mismo (posible señal de autoridad)
# - número de enlaces internos
